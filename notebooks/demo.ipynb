# %% [markdown]
# # DataJoint Element for Calcium Imaging
#
# + This notebook briefly demonstrates using the open-source DataJoint Element for
# calcium imaging.
# + For a detailed tutorial, please see the [tutorial notebook](./tutorial.ipynb).

# %% [markdown]
# <img src =../docs/src/images/rawscans.gif title="value" width="200" height="200"/>
# <img src =../docs/src/images/motioncorrectedscans.gif width="200" height="200"/>
# <img src =../docs/src/images/cellsegmentation.png width="200" height="200"/>
# <img src =../docs/src/images/calciumtraces.png width="200" height="200"/>
#
# Left to right: Raw scans, Motion corrected scans, Cell segmentations, Calcium events

# %% [markdown]
# ### Import dependencies

# %%
from tests.tutorial_pipeline import *
# Out:
# [2024-06-11 05:39:32,510][WARNING]: lab.Project and related tables will be removed in a future version of Element Lab. Please use the project schema.
# [2024-06-11 05:39:32,512][INFO]: Connecting root@fakeservices.datajoint.io:3306
# [2024-06-11 05:39:32,516][INFO]: Connected root@fakeservices.datajoint.io:3306

# %% [markdown]
# ### View workflow

# %%
(
    dj.Diagram(subject.Subject)
    + dj.Diagram(session.Session)
    + dj.Diagram(scan)
    + dj.Diagram(imaging)
)

# %% [markdown]
# ### Insert an entry in a manual table by calling the `insert()` method
#
# ```python
#
# subject.Subject.insert1(
#      dict(subject='subject1',
#           subject_birth_date='2023-01-01',
#           sex='U'
#      )
# )
# ```

# %% [markdown]
# ### Automatically process data with the `populate()` method
#
# + Once data is inserted into manual tables, the `populate()` function automatically runs the ingestion and processing routines.
#
# + For example, to run Suite2p processing in the `Processing` table:
#
#      ```python
#      imaging.Processing.populate()
#      ```

# %% [markdown]
# ### Visualize processed data

# %%
from element_calcium_imaging.plotting.widget import main

main(imaging)
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Result:', layout=Layout(display='flex', flex_flow='row', g…
# ---------------------------------------------------------------------------
# DataJointError                            Traceback (most recent call last)
# File /workspaces/element-calcium-imaging/element_calcium_imaging/plotting/widget.py:165, in main.<locals>.response(change, usedb)
#     163         fig2_widget.data[1].y = None
#     164 else:
# --> 165     background_with_cells, cells_maskid_image = cell_plot.figure_data(
#     166         imaging, motioncorrection_dropdown.value
#     167     )
#     169     with fig1_widget.batch_update():
#     170         fig1_widget.data[0].z = background_with_cells
#
# File /workspaces/element-calcium-imaging/element_calcium_imaging/plotting/cell_plot.py:116, in figure_data(imaging, segmentation_key)
#     103 def figure_data(imaging, segmentation_key) -> Tuple[np.array, np.array]:
#     104     """Prepare the images for a given segmentation_key.
#     105
#     106     Args:
#    (...)
#     113         cells_maskid_image (np.array): Mask ID image.
#     114     """
# --> 116     image = (imaging.MotionCorrection.Summary & segmentation_key).fetch1(
#     117         "average_image"
#     118     )
#     120     cell_mask_ids, mask_xpix, mask_ypix = (
#     121         imaging.Segmentation.Mask * imaging.MaskClassification.MaskType
#     122         & segmentation_key
#     123     ).fetch("mask", "mask_xpix", "mask_ypix")
#     125     background_with_cells, cells_maskid_image = mask_overlayed_image(
#     126         image, mask_xpix, mask_ypix, cell_mask_ids, low_q=0, high_q=0.99
#     127     )
#
# File /usr/local/lib/python3.9/site-packages/datajoint/user_tables.py:60, in TableMeta.__and__(cls, arg)
#      59 def __and__(cls, arg):
# ---> 60     return cls() & arg
#
# File /usr/local/lib/python3.9/site-packages/datajoint/expression.py:226, in QueryExpression.__and__(self, restriction)
#     220 def __and__(self, restriction):
#     221     """
#     222     Restriction operator e.g. ``q1 & q2``.
#     223     :return: a restricted copy of the input argument
#     224     See QueryExpression.restrict for more detail.
#     225     """
# --> 226     return self.restrict(restriction)
#
# File /usr/local/lib/python3.9/site-packages/datajoint/expression.py:190, in QueryExpression.restrict(self, restriction)
#     145 """
#     146 Produces a new expression with the new restriction applied.
#     147 rel.restrict(restriction)  is equivalent to  rel & restriction.
#    (...)
#     187 string, or an AndList.
#     188 """
#     189 attributes = set()
# --> 190 new_condition = make_condition(self, restriction, attributes)
#     191 if new_condition is True:
#     192     return self  # restriction has no effect, return the same object
#
# File /usr/local/lib/python3.9/site-packages/datajoint/condition.py:262, in make_condition(query_expression, condition, columns)
#     260     or_list = [make_condition(query_expression, q, columns) for q in condition]
#     261 except TypeError:
# --> 262     raise DataJointError("Invalid restriction type %r" % condition)
#     263 else:
#     264     or_list = [
#     265         item for item in or_list if item is not False
#     266     ]  # ignore False conditions
#
# DataJointError: Invalid restriction type None

# %% [markdown]
# For an in-depth tutorial please see the [tutorial notebook](./tutorial.ipynb).
